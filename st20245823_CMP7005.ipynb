# %%
# importing the necessary libraries for data analysis
import pandas as pd
import numpy as np
import glob

# %%
# Combine all city data into one big table
city_files = glob.glob("Dataset/*.csv")

all_cities_data = []


for file_name in city_files:
    
    city_df = pd.read_csv(file_name)
    all_cities_data.append(city_df)
    print(f"Loaded: {file_name}")
    
    
combined_data = pd.concat(all_cities_data, ignore_index=True)


#Save the combined data to a new CSV file
#combined_data.to_csv("all_cities_combined.csv", index=False)


print(f"SUCCESS: Combined {len(city_files)} city files into one table with {len(combined_data)} total rows")
# Out:
# Loaded: Dataset\PRSA_Data_Changping_20130301-20170228.csv
# Loaded: Dataset\PRSA_Data_Dongsi_20130301-20170228.csv
# Loaded: Dataset\PRSA_Data_Guanyuan_20130301-20170228.csv
# Loaded: Dataset\PRSA_Data_Shunyi_20130301-20170228.csv
# SUCCESS: Combined 4 city files into one table with 140256 total rows

# %%
#df= pd.read_csv('all_cities_combined.csv')
#df

combined_data
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0           1  2013      3    1     0    3.0   6.0  13.0   7.0   300.0  85.0
# 1           2  2013      3    1     1    3.0   3.0   6.0   6.0   300.0  85.0
# 2           3  2013      3    1     2    3.0   3.0  22.0  13.0   400.0  74.0
# 3           4  2013      3    1     3    3.0   6.0  12.0   8.0   300.0  81.0
# 4           5  2013      3    1     4    3.0   3.0  14.0   8.0   300.0  81.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 140251  35060  2017      2   28    19   27.0  72.0   8.0  92.0   800.0  16.0
# 140252  35061  2017      2   28    20   47.0  55.0  17.0  86.0  1100.0  19.0
# 140253  35062  2017      2   28    21   18.0  28.0   4.0  30.0   500.0  64.0
# 140254  35063  2017      2   28    22   18.0  20.0   9.0  33.0   500.0  59.0
# 140255  35064  2017      2   28    23   15.0  22.0  13.0  34.0   500.0  60.0
#
#         TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 0       -2.3  1020.8 -19.7   0.0    E   0.5  Changping
# 1       -2.5  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2       -3.0  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3       -3.6  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4       -3.5  1022.3 -19.4   0.0    N   2.1  Changping
# ...      ...     ...   ...   ...  ...   ...        ...
# 140251  10.3  1014.2 -12.4   0.0    W   1.8     Shunyi
# 140252   9.8  1014.5  -9.9   0.0   NW   1.5     Shunyi
# 140253   9.1  1014.6 -12.7   0.0   NE   1.7     Shunyi
# 140254   7.1  1015.2 -13.2   0.0  WNW   1.8     Shunyi
# 140255   7.4  1014.9 -11.9   0.0    N   1.4     Shunyi
#
# [140256 rows x 18 columns]
